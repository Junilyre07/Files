# %% [markdown]
# # MEAN, MEDIAN, MODE, STANDARD DIV, VARIANCE and MIN-MAX.
#
# Mean, median, and mode are three kinds of "averages". There are many "averages" in statistics, but these are, the three most common, and are certainly the three that are most likely to encounter in your pre-statistics courses.
#
# The "Mean" is the "average" you're used to, where you add up all the numbers and then divide by the number of numbers.
# The "Median" is the "middle" value in the list of numbers. To find the median, your numbers have to be listed in numerical order from smallest to largest, so you may have to rewrite your list before you can find the median.
# The "Mode" is the value that occurs most often. If no number in the list is repeated, then there is no mode for the list.
#
# The Standard Deviation is a measure of how spread out numbers are.
# Its symbol is σ (the greek letter sigma), in short, it is the square root of the Variance.
#
# The "Variance" is the average of the squared differences from the Mean.
#
# The "Min-Max", obviously, the min is simply the lowest observation, while the max is the highest observation.
# Basically, it is easiest to determine the min and max if the data are ordered from lowest to highest.

# %%
# %matplotlib inline 
import pandas as pd
import matplotlib.pyplot as plt
file = r'___________'

#create your own dataset with at least 5 columns
#you can source out data from internet. 

df = pd.read_csv('vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
print(df.isnull().sum())
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# Check for duplicates in the entire dataframe
if df.duplicated().any():
    print("Dataframe contains duplicates")
else:
    print("Dataframe does not contain duplicates")
# Out:
# Dataframe does not contain duplicates

# %%
df['Year'].fillna('Unknown_year', inplace=True)
df['Publisher'].fillna('Unknown_publisher', inplace=True)
print(df.isnull().sum())
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# Q1. insert your explanation about the cell above (Note that you can convert a cell into MARKDOWN so you can incidate your comments)

# %%
import numpy
# df = pd.read_csv(file)
mean1 = df['Global_Sales'].mean()
sum1 = df['Global_Sales'].sum()
max1 = df['Global_Sales'].max()
min1 = df['Global_Sales'].min()
count1 = df['Global_Sales'].count()
median1 = df['Global_Sales'].median() 
std1 = df['Global_Sales'].std() 
var1 = df['Global_Sales'].var() 

print(df.shape)
#y, x variables in the given data set.
# Out:
# (16598, 11)

# %%
print ('Mean Global Sales: ' + str(mean1))
print ('Sum of Global Sales:' + str(sum1))
print ('Max Global Sales:' + str(max1))
print ('Min Global Sales:' + str(min1))
print ('Count of Global Sales: ' + str(count1))
print ('Median Global Sales:' + str(median1))
print ('Variance of Global Sales:' + str(var1))
print ('Standard Deviation of Global Sales:' + str(std1))
# Out:
# Mean Global Sales: 0.53744065550074
# Sum of Global Sales:8920.44
# Max Global Sales:82.74
# Min Global Sales:0.01
# Count of Global Sales: 16598
# Median Global Sales:0.17
# Variance of Global Sales:2.4181118804027917
# Standard Deviation of Global Sales:1.5550279355699022

# %%
Vgsales_sample = df.sample(n = 100, random_state = 0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

#show chart for variable 1
plt.figure(figsize=(8,4)) # this creates a figure 8 inch wide, 4 inch high
sns.countplot(Vgsales_sample['Platform'], label="")
plt.show()

#show chart for variable 2
ax = sns.countplot(Vgsales_sample['Genre'], label="")
ax.set_xticklabels(ax.get_xticklabels(), fontsize=7)
plt.tight_layout()
plt.show()

#show chart for variable 3
ax = sns.countplot(Vgsales_sample['Publisher'], label="")
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Romelio Villar Jr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Romelio Villar Jr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Romelio Villar Jr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %% [markdown]
# Q2. insert your explanation about the cell above

# %% [markdown]
# Q3. insert your explanation about the cell above

# %% [markdown]
# Q4. insert your explanation about the cell above

# %%
import pylab as pl

# %%
#create histogram comparing to other column

df.drop('Global_Sales', axis=1).hist(bins=3, figsize=(5,3))
pl.suptitle("Histogram")
plt.savefig('Global_Sales')
plt.show()

df.drop('Year', axis=1).hist(bins=3, figsize=(5,3))
pl.suptitle("Histogram")
plt.savefig('Year')
plt.show()

3
# Out:
# 3

# %% [markdown]
# Q5. insert your explanation about the cell above

# %%
# from pandas.tools.plotting import scatter_matrix
from pandas.plotting import scatter_matrix
from matplotlib import cm

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["Genre_encoded"] = le.fit_transform(df["Genre"])
df["Platform_encoded"] = le.fit_transform(df["Platform"])
df["Publisher_encoded"] = le.fit_transform(df["Publisher"])
print(df.head())
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Genre_encoded  \
# 0     41.49     29.02      3.77         8.46         82.74             10
# 1     29.08      3.58      6.81         0.77         40.24              4
# 2     15.85     12.88      3.79         3.31         35.82              6
# 3     15.75     11.01      3.28         2.96         33.00             10
# 4     11.27      8.89     10.22         1.00         31.37              7
#
#    Platform_encoded  Publisher_encoded
# ...

# %%
feature_names = (['Genre_encoded','Platform_encoded', 'Publisher_encoded'])
X = df[feature_names]
y = df['Global_Sales']

cmap = cm.get_cmap('gnuplot')
scatter = scatter_matrix(X, c = y, marker = 'o', s= 40, hist_kwds ={'bins':15}, figsize=(9,9), cmap = cmap)
plt.suptitle('Scatter-matrix for each input variable')
plt.savefig('Sample_scatter_matrix')

# %% [markdown]
# Q6. insert your explanation about the cell above

# %%
feature_names = (['EU_Sales', 'JP_Sales', 'Other_Sales'])
X = df[feature_names]
y = df['Global_Sales']

cmap = cm.get_cmap('gnuplot')
scatter = scatter_matrix(X, c = y, marker = 'o', s= 40, hist_kwds ={'bins':15}, figsize=(9,9), cmap = cmap)
plt.suptitle('Scatter-matrix for each input variable')
plt.savefig('Sample_scatter_matrix')

# %%
#another way to get mean,median,standard deviation, variance...etc...
df.describe()
# Out:
#                Rank      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254      0.264667      0.146652      0.077782      0.048063
# std     4791.853933      0.816683      0.505351      0.309291      0.188588
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%     4151.250000      0.000000      0.000000      0.000000      0.000000
# 50%     8300.500000      0.080000      0.020000      0.000000      0.010000
# 75%    12449.750000      0.240000      0.110000      0.040000      0.040000
# max    16600.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global_Sales  Genre_encoded  Platform_encoded  Publisher_encoded
# count  16598.000000   16598.000000      16598.000000       16598.000000
# mean       0.537441       4.928124         15.797988         294.482769
# ...

# %% [markdown]
# Q7. insert your explanation about the cell above

# %% [markdown]
# Q8. Discuss your learnings on this activity

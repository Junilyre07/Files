# %%
import numpy as np 
import pandas as pd 

# For visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# For apriori and association rules
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
# Load dataset
df = pd.read_csv('Retail.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0  01/12/2010 8:26       2.55     17850.0  United Kingdom
# 1  01/12/2010 8:26       3.39     17850.0  United Kingdom
# 2  01/12/2010 8:26       2.75     17850.0  United Kingdom
# 3  01/12/2010 8:26       3.39     17850.0  United Kingdom
# 4  01/12/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
if df['InvoiceNo'].str.contains('C|[^0-9]+').any():
    print("There are 'C' or string values in the InvoiceNo column")
else:
    print("There are no 'C' or string values in the InvoiceNo column")
# Out:
# There are 'C' or string values in the InvoiceNo column

# %%
# check for 'C' in InvoiceNo column
contains_c = df['InvoiceNo'].str.contains('C')
print(contains_c.any()) # True if there's at least one 'C' in InvoiceNo column

# check for non-numeric characters in InvoiceNo column
non_numeric = df['InvoiceNo'].str.contains('[^0-9]+')
print(non_numeric.any()) # True if there's at least one non-numeric character in InvoiceNo column
# Out:
# True
# True

# %%
# Data Preprocessing 
#1.) Removing nulls and whitespaces 

if df.isnull().values.any():
    print("Dataframe contains null values")
else:
    print("Dataframe does not contain null values")
# Out:
# Dataframe contains null values

# %%
# Check for duplicates in the entire dataframe
if df.duplicated().any():
    print("Dataframe contains duplicates")
else:
    print("Dataframe does not contain duplicates")
# Out:
# Dataframe contains duplicates

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace = True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('B|[^0-9]+')]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL       6.0
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL       4.0
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT       3.0
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0        01/12/2010 8:26       2.55     17850.0  United Kingdom
# 1        01/12/2010 8:26       3.39     17850.0  United Kingdom
# 2        01/12/2010 8:26       2.75     17850.0  United Kingdom
# 3        01/12/2010 8:26       3.39     17850.0  United Kingdom
# 4        01/12/2010 8:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  09/12/2011 12:50       0.85     12680.0          France
# 541905  09/12/2011 12:50       2.10     12680.0          France
# 541906  09/12/2011 12:50       4.15     12680.0          France
# 541907  09/12/2011 12:50       4.15     12680.0          France
# 541908  09/12/2011 12:50       4.95     12680.0          France
#
# [529502 rows x 8 columns]

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587     22899      CHILDREN'S APRON DOLLY GIRL       6.0
# 541906    581587     23254     CHILDRENS CUTLERY DOLLY GIRL       4.0
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587     22138     BAKING SET 9 PIECE RETROSPOT       3.0
#
#              InvoiceDate  UnitPrice  CustomerID Country
# 541904  09/12/2011 12:50       0.85     12680.0  France
# 541905  09/12/2011 12:50       2.10     12680.0  France
# 541906  09/12/2011 12:50       4.15     12680.0  France
# 541907  09/12/2011 12:50       4.15     12680.0  France
# 541908  09/12/2011 12:50       4.95     12680.0  France

# %%
basket = (df[df['Country'] == "United Kingdom"]
         .groupby(['InvoiceNo', 'Description'])['Quantity']
         .sum().unstack().reset_index().fillna(0)
         .set_index('InvoiceNo'))
basket
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
# ...                            ...                      ...
# 581582                         0.0                      0.0
# 581583                         0.0                      0.0
# 581584                         0.0                      0.0
# 581585                         0.0                      0.0
# 581586                         0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
# ...                             ...                         ...
# 581582                          0.0                         0.0
# 581583                          0.0                         0.0
# 581584                          0.0                         0.0
# 581585                          0.0                         0.0
# 581586                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
# ...                                ...                        ...
# 581582                             0.0                        0.0
# 581583                             0.0                        0.0
# 581584                             0.0                        0.0
# 581585                             0.0                        0.0
# 581586                             0.0                        0.0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                0.0                               0.0
# 536366                                0.0                               0.0
# 536367                                0.0                               0.0
# 536368                                0.0                               0.0
# 536369                                0.0                               0.0
# ...                                   ...                               ...
# 581582                                0.0                               0.0
# 581583                                0.0                               0.0
# 581584                                0.0                               0.0
# 581585                                0.0                               0.0
# 581586                                0.0                               0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
# ...                                      ...                            ...
# 581582                                   0.0                            0.0
# 581583                                   0.0                            0.0
# 581584                                   0.0                            0.0
# 581585                                   0.0                            0.0
# 581586                                   0.0                            0.0
#
# Description  ...  label mix up  mystery! Only ever imported 1800  \
# InvoiceNo    ...
# 536365       ...           0.0                               0.0
# 536366       ...           0.0                               0.0
# 536367       ...           0.0                               0.0
# 536368       ...           0.0                               0.0
# 536369       ...           0.0                               0.0
# ...          ...           ...                               ...
# 581582       ...           0.0                               0.0
# 581583       ...           0.0                               0.0
# 581584       ...           0.0                               0.0
# 581585       ...           0.0                               0.0
# 581586       ...           0.0                               0.0
#
# Description  on cargo order  printing smudges/thrown away  \
# InvoiceNo
# 536365                  0.0                           0.0
# 536366                  0.0                           0.0
# 536367                  0.0                           0.0
# 536368                  0.0                           0.0
# 536369                  0.0                           0.0
# ...                     ...                           ...
# 581582                  0.0                           0.0
# 581583                  0.0                           0.0
# 581584                  0.0                           0.0
# 581585                  0.0                           0.0
# 581586                  0.0                           0.0
#
# Description  rcvd be air temp fix for dotcom sit  re dotcom quick fix.  \
# InvoiceNo
# 536365                                       0.0                   0.0
# 536366                                       0.0                   0.0
# 536367                                       0.0                   0.0
# 536368                                       0.0                   0.0
# 536369                                       0.0                   0.0
# ...                                          ...                   ...
# 581582                                       0.0                   0.0
# 581583                                       0.0                   0.0
# 581584                                       0.0                   0.0
# 581585                                       0.0                   0.0
# 581586                                       0.0                   0.0
#
# Description  re-adjustment  samples  samples/damages  smashed
# InvoiceNo
# 536365                 0.0      0.0              0.0      0.0
# 536366                 0.0      0.0              0.0      0.0
# 536367                 0.0      0.0              0.0      0.0
# 536368                 0.0      0.0              0.0      0.0
# 536369                 0.0      0.0              0.0      0.0
# ...                    ...      ...              ...      ...
# 581582                 0.0      0.0              0.0      0.0
# 581583                 0.0      0.0              0.0      0.0
# 581584                 0.0      0.0              0.0      0.0
# 581585                 0.0      0.0              0.0      0.0
# 581586                 0.0      0.0              0.0      0.0
#
# [18019 rows x 4018 columns]

# %%
item_counts = df[df['Country'] == 'United Kingdom'].groupby('Description')['InvoiceNo'].nunique().reset_index()
item_counts.columns = ['Description', 'Count']
item_counts = item_counts.sort_values('Count', ascending=False).reset_index(drop=True)

# %%
item_counts.head(10).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_5322d_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5322d_row1_col1 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_5322d_row2_col1 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_5322d_row3_col1 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_5322d_row4_col1 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_5322d_row5_col1 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_5322d_row6_col1 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_5322d_row7_col1 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_5322d_row8_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_5322d_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_5322d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5322d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5322d_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5322d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5322d_row0_col0" class="data row0 col0" >WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td id="T_5322d_row0_col1" class="data row0 col1" >2166</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5322d_row1_col0" class="data row1 col0" >JUMBO BAG RED RETROSPOT</td>
#       <td id="T_5322d_row1_col1" class="data row1 col1" >1938</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5322d_row2_col0" class="data row2 col0" >REGENCY CAKESTAND 3 TIER</td>
#       <td id="T_5322d_row2_col1" class="data row2 col1" >1685</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5322d_row3_col0" class="data row3 col0" >PARTY BUNTING</td>
#       <td id="T_5322d_row3_col1" class="data row3 col1" >1594</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5322d_row4_col0" class="data row4 col0" >LUNCH BAG RED RETROSPOT</td>
#       <td id="T_5322d_row4_col1" class="data row4 col1" >1392</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5322d_row5_col0" class="data row5 col0" >ASSORTED COLOUR BIRD ORNAMENT</td>
#       <td id="T_5322d_row5_col1" class="data row5 col1" >1371</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5322d_row6_col0" class="data row6 col0" >SET OF 3 CAKE TINS PANTRY DESIGN</td>
#       <td id="T_5322d_row6_col1" class="data row6 col1" >1241</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5322d_row7_col0" class="data row7 col0" >NATURAL SLATE HEART CHALKBOARD</td>
#       <td id="T_5322d_row7_col1" class="data row7 col1" >1219</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5322d_row8_col0" class="data row8 col0" >LUNCH BAG  BLACK SKULL.</td>
#       <td id="T_5322d_row8_col1" class="data row8 col1" >1216</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5322d_row9_col0" class="data row9 col0" >HEART OF WICKER SMALL</td>
#       <td id="T_5322d_row9_col1" class="data row9 col1" >1164</td>
#     </tr>
#   </tbody>
# </table>

# %%
def encode_units(x):
    if x <=0:
       return 0
    if x >= 1:
       return 1
basket_sets = basket.applymap(encode_units)
basket_sets.drop(basket_sets.filter(like='wrong' and 'wet').columns, axis=1, inplace=True)
basket_sets = basket_sets.astype(bool)
basket_sets
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                       False                    False
# 536366                       False                    False
# 536367                       False                    False
# 536368                       False                    False
# 536369                       False                    False
# ...                            ...                      ...
# 581582                       False                    False
# 581583                       False                    False
# 581584                       False                    False
# 581585                       False                    False
# 581586                       False                    False
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                        False                       False
# 536366                        False                       False
# 536367                        False                       False
# 536368                        False                       False
# 536369                        False                       False
# ...                             ...                         ...
# 581582                        False                       False
# 581583                        False                       False
# 581584                        False                       False
# 581585                        False                       False
# 581586                        False                       False
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                           False                      False
# 536366                           False                      False
# 536367                           False                      False
# 536368                           False                      False
# 536369                           False                      False
# ...                                ...                        ...
# 581582                           False                      False
# 581583                           False                      False
# 581584                           False                      False
# 581585                           False                      False
# 581586                           False                      False
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                              False                             False
# 536366                              False                             False
# 536367                              False                             False
# 536368                              False                             False
# 536369                              False                             False
# ...                                   ...                               ...
# 581582                              False                             False
# 581583                              False                             False
# 581584                              False                             False
# 581585                              False                             False
# 581586                              False                             False
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                 False                          False
# 536366                                 False                          False
# 536367                                 False                          False
# 536368                                 False                          False
# 536369                                 False                          False
# ...                                      ...                            ...
# 581582                                 False                          False
# 581583                                 False                          False
# 581584                                 False                          False
# 581585                                 False                          False
# 581586                                 False                          False
#
# Description  ...  label mix up  mystery! Only ever imported 1800  \
# InvoiceNo    ...
# 536365       ...         False                             False
# 536366       ...         False                             False
# 536367       ...         False                             False
# 536368       ...         False                             False
# 536369       ...         False                             False
# ...          ...           ...                               ...
# 581582       ...         False                             False
# 581583       ...         False                             False
# 581584       ...         False                             False
# 581585       ...         False                             False
# 581586       ...         False                             False
#
# Description  on cargo order  printing smudges/thrown away  \
# InvoiceNo
# 536365                False                         False
# 536366                False                         False
# 536367                False                         False
# 536368                False                         False
# 536369                False                         False
# ...                     ...                           ...
# 581582                False                         False
# 581583                False                         False
# 581584                False                         False
# 581585                False                         False
# 581586                False                         False
#
# Description  rcvd be air temp fix for dotcom sit  re dotcom quick fix.  \
# InvoiceNo
# 536365                                     False                 False
# 536366                                     False                 False
# 536367                                     False                 False
# 536368                                     False                 False
# 536369                                     False                 False
# ...                                          ...                   ...
# 581582                                     False                 False
# 581583                                     False                 False
# 581584                                     False                 False
# 581585                                     False                 False
# 581586                                     False                 False
#
# Description  re-adjustment  samples  samples/damages  smashed
# InvoiceNo
# 536365               False    False            False    False
# 536366               False    False            False    False
# 536367               False    False            False    False
# 536368               False    False            False    False
# 536369               False    False            False    False
# ...                    ...      ...              ...      ...
# 581582               False    False            False    False
# 581583               False    False            False    False
# 581584               False    False            False    False
# 581585               False    False            False    False
# 581586               False    False            False    False
#
# [18019 rows x 4018 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.02, use_colnames=True)
rules = association_rules(frequent_itemsets, metric ='lift', min_threshold=.5)
print(rules.head())
# Out:
#                          antecedents                        consequents  \
# 0      (60 TEATIME FAIRY CAKE CASES)  (PACK OF 72 RETROSPOT CAKE CASES)
# 1  (PACK OF 72 RETROSPOT CAKE CASES)      (60 TEATIME FAIRY CAKE CASES)
# 2         (ALARM CLOCK BAKELIKE RED)       (ALARM CLOCK BAKELIKE GREEN)
# 3       (ALARM CLOCK BAKELIKE GREEN)         (ALARM CLOCK BAKELIKE RED)
# 4         (ALARM CLOCK BAKELIKE RED)        (ALARM CLOCK BAKELIKE PINK)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.041789            0.062656  0.022698    0.543161   8.668922
# 1            0.062656            0.041789  0.022698    0.362267   8.668922
# 2            0.051612            0.048615  0.031245    0.605376  12.452370
# 3            0.048615            0.051612  0.031245    0.642694  12.452370
# 4            0.051612            0.036406  0.021810    0.422581  11.607440
#
#    leverage  conviction  zhangs_metric
# 0  0.020080    2.051802       0.923226
# 1  0.020080    1.502528       0.943779
# 2  0.028736    2.410866       0.969745
# 3  0.028736    2.654274       0.966690
# 4  0.019931    1.668794       0.963581

# %%
rules[(rules['lift']>=6) &
(rules['confidence'] >=0.8)]
# Out:
#                                            antecedents  \
# 25                    (PINK REGENCY TEACUP AND SAUCER)
# 187  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 188  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 192  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...
# 198  (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)
#
#                            consequents  antecedent support  \
# 25   (GREEN REGENCY TEACUP AND SAUCER)            0.039014
# 187  (ROSES REGENCY TEACUP AND SAUCER)            0.032022
# 188  (GREEN REGENCY TEACUP AND SAUCER)            0.030301
# 192          (JUMBO BAG RED RETROSPOT)            0.025196
# 198          (JUMBO BAG RED RETROSPOT)            0.028026
#
#      consequent support   support  confidence       lift  leverage  \
# 25             0.051834  0.032022    0.820768  15.834498  0.029999
# 187            0.053111  0.027360    0.854419  16.087548  0.025659
# 188            0.051834  0.027360    0.902930  17.419596  0.025789
# 192            0.107553  0.020312    0.806167   7.495527  0.017602
# 198            0.107553  0.022476    0.801980   7.456595  0.019462
#
#      conviction  zhangs_metric
# 25     5.290163       0.974881
# 187    6.504228       0.968865
# 188    9.767897       0.972048
# 192    4.604214       0.888986
# 198    4.506857       0.890858

# %%
rules[(rules['lift']>=5) &
(rules['confidence'] >=0.7)]
# Out:
#                                            antecedents  \
# 8                        (CHARLOTTE BAG PINK POLKADOT)
# 23                 (GARDENERS KNEELING PAD CUP OF TEA)
# 25                    (PINK REGENCY TEACUP AND SAUCER)
# 28                   (GREEN REGENCY TEACUP AND SAUCER)
# 29                   (ROSES REGENCY TEACUP AND SAUCER)
# 165                   (PINK REGENCY TEACUP AND SAUCER)
# 184              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 185               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 186  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
# 187  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 188  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 191                   (PINK REGENCY TEACUP AND SAUCER)
# 192  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...
# 198  (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)
# 204  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO STOR...
#
#                                            consequents  antecedent support  \
# 8                        (RED RETROSPOT CHARLOTTE BAG)            0.037405
# 23                  (GARDENERS KNEELING PAD KEEP CALM)            0.041623
# 25                   (GREEN REGENCY TEACUP AND SAUCER)            0.039014
# 28                   (ROSES REGENCY TEACUP AND SAUCER)            0.051834
# 29                   (GREEN REGENCY TEACUP AND SAUCER)            0.053111
# 165                  (ROSES REGENCY TEACUP AND SAUCER)            0.039014
# 184               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.028248
# 185              (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.026583
# 186                   (PINK REGENCY TEACUP AND SAUCER)            0.038903
# 187                  (ROSES REGENCY TEACUP AND SAUCER)            0.032022
# 188                  (GREEN REGENCY TEACUP AND SAUCER)            0.030301
# 191  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...            0.039014
# 192                          (JUMBO BAG RED RETROSPOT)            0.025196
# 198                          (JUMBO BAG RED RETROSPOT)            0.028026
# 204                          (JUMBO BAG RED RETROSPOT)            0.028470
#
#      consequent support   support  confidence       lift  leverage  \
# 8              0.050225  0.026583    0.710682  14.150042  0.024704
# 23             0.049836  0.030024    0.721333  14.474059  0.027950
# 25             0.051834  0.032022    0.820768  15.834498  0.029999
# 28             0.053111  0.038903    0.750535  14.131553  0.036150
# 29             0.051834  0.038903    0.732497  14.131553  0.036150
# 165            0.053111  0.030301    0.776671  14.623659  0.028229
# 184            0.026583  0.020423    0.722986  27.197263  0.019672
# 185            0.028248  0.020423    0.768267  27.197263  0.019672
# 186            0.039014  0.027360    0.703281  18.026203  0.025842
# 187            0.053111  0.027360    0.854419  16.087548  0.025659
# 188            0.051834  0.027360    0.902930  17.419596  0.025789
# 191            0.038903  0.027360    0.701280  18.026203  0.025842
# 192            0.107553  0.020312    0.806167   7.495527  0.017602
# 198            0.107553  0.022476    0.801980   7.456595  0.019462
# 204            0.107553  0.021311    0.748538   6.959704  0.018249
#
#      conviction  zhangs_metric
# 8      3.282813       0.965441
# 23     3.409678       0.971341
# 25     5.290163       0.974881
# 28     3.795685       0.980036
# 29     3.544511       0.981357
# 165    4.239893       0.969440
# 184    3.513966       0.991232
# 185    4.193416       0.989536
# 186    3.238706       0.982758
# 187    6.504228       0.968865
# 188    9.767897       0.972048
# 191    3.217385       0.982871
# 192    4.604214       0.888986
# 198    4.506857       0.890858
# 204    3.549033       0.881409
